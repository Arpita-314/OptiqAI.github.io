# %%
# Clone repository
git clone https://github.com/Arpita-314/quant-research.git
cd quant-research

# Run automated setup
chmod +x setup.sh
./setup.sh
# Out:
#   Cell In[1], line 2
#     git clone https://github.com/Arpita-314/quant-research.git
#         ^
# SyntaxError: invalid syntax

# %%
# Edit .env file
nano .env

# Add your Anthropic API key (for Agentic RL)
ANTHROPIC_API_KEY=your_key_here
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # Edit .env file
# ----> 2 nano .env
#       4 # Add your Anthropic API key (for Agentic RL)
#       5 ANTHROPIC_API_KEY=your_key_here
#
# NameError: name 'nano' is not defined

# %%
docker-compose up -d
# Out:
#   Cell In[3], line 1
#     docker-compose up -d
#                    ^
# SyntaxError: invalid syntax

# %%
# Activate virtual environment
source venv/bin/activate

# Portfolio Optimizer (recommended first)
streamlit run src/project3_portfolio/dashboard.py
# Out:
#   Cell In[4], line 2
#     source venv/bin/activate
#            ^
# SyntaxError: invalid syntax

# %%
streamlit run src/project3_portfolio/dashboard.py
